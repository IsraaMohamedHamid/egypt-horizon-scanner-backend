# %%
import random
import json
import os
import pandas as pd

# %%
# Replace 'geojson_data.json' with the path to your actual GeoJSON file
json_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/json/governorates.json'

try:
    with open(json_file_path, 'r') as file:
        data = json.load(file)
    
    # Extracting ADM1_EN values from features
    adm1_en_values = [feature['properties']['ADM1_EN'] for feature in data['features']]
    print(adm1_en_values)
    
except FileNotFoundError:
    print(f"The file {json_file_path} does not exist.")
except json.JSONDecodeError:
    print(f"The file {json_file_path} is not a valid JSON or GeoJSON file.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
list1 = [
    "6 October-1 (k)",
    "6 October-2 (k)",
    "10 Ramadan 1 (k)",
    "10 Ramadan 2 (k)",
    "15 Mayu (k)",
    "Abdin (k)",
    "Abnub (m)",
    "Abu-l-Matamir (m)",
    "Abu Hammad (m)",
    "Abu Hummus (m)",
    "Abu Kebir (m)",
    "Abu Qirqas (m)",
    "Abu Radis (k)",
    "Abu Simbel (m)",
    "Abu Tig (m)",
    "Abu Tisht (m)",
    "Abu Zenima (k)",
    "Aga (m)",
    "Al-Aguza (k)",
    "Ain Shams (k)",
    "Akhmim City (m)",
    "Alexandria Port Police Department (p)",
    "Amreya (k)",
    "El Arish 1 (k)",
    "El Arish 2 (k)",
    "El Arish 3 (k)",
    "El Arish 4 (k)",
    "Armant (m)",
    "Ashmun (m)",
    "Aswan City (k)",
    "Aswan (m)",
    "Assuit (m)",
    "Assuit City 1 (k)",
    "Assuit City 2 (k)",
    "Ataqa (k)",
    "Atfeh (m)",
    "Awlad Saqr (m)",
    "Awsim (m)",
    "Al-Azbakiyya (k)",
    "Bab Al-Shariyya (k)",
    "Bab Sharqi (k)",
    "Badrashain (k)",
    "Badr (m)",
    "Banha (k)",
    "Banha (m)",
    "Baris Police (m)",
    "Basyun (m)",
    "Bany Abeed (m)",
    "Beni Mazar (m)",
    "Bani Swayf City (k)",
    "Bani Swayf (m)",
    "Biba (m)",
    "Bilbis (m)",
    "Bilqas (m)",
    "Bir Al-Abd (k)",
    "Birkat Al-Sab (m)",
    "Biyalu (m)",
    "Burg al-Arab (m)",
    "Burg Al-Arab City (k)",
    "Bulaq (k)",
    "Bulaq Al-DakrUr (k)",
    "Burullus (m)",
    "Dahab (k)",
    "Dayrut (m)",
    "Damanhur (k)",
    "Damanhur (m)",
    "Dumyat (m)",
    "Dumyat 1 (k)",
    "Dumyat 2 (k)",
    "Dar al-Salam (m)",
    "Daraw (m)",
    "Deir Mawas (m)",
    "Dikirnis (m)",
    "Dekhela (k)",
    "Disuq (k)",
    "Disuq (m)",
    "Dishna (m)",
    "Dyarb Nigm (m)",
    "Dokki (k)",
    "Edfu (m)",
    "Edku (m)",
    "Al-Ahram (k)",
    "Al-Arab (k)",
    "Al-Arbiin (k)",
    "Al-Attarin (k)",
    "El Ayyat (m)",
    "Al- Badari (m)",
    "Al-Badrashein (m)",
    "Al-Bagur (m)",
    "Al-Balyana (m)",
    "El Basal Port (k)",
    "Al-Basatin (k)",
    "Al-Dabaa (k)",
    "Al-Dar Al-Ahmar (k)",
    "Al-Dawahy (k)",
    "Al-Dilingat (m)",
    "Al-Fashn (m)",
    "Al-Fath (m)",
    "Al-Gamaliya (k)",
    "Al-Gamaliya (m)",
    "Al-Ganayin (k)",
    "Al-Ghanayem (m)",
    "Al-Gomrok (k)",
    "Al-Hammam (k)",
    "Al-Hamool (m)",
    "Al-Hasna (k)",
    "Al-Hawamdiya (k)",
    "Al-Husayniya (m)",
    "El-Ibrahimiya (m)",
    "Al-Idwa (m)",
    "Al-Kawsar (k)",
    "Al-Khalifa (k)",
    "Al-Labban (k)",
    "El Mahalla El Kobra (m)",
    "El Mahalla El Kobra 1 (k)",
    "El Mahalla El Kobra 2 (k)",
    "Al-Mahmudiyya (m)",
    "Al-Manakh (k)",
    "Al-Manasra (k)",
    "Al-Mansha (m)",
    "El-Mansheya (k)",
    "Al-Manzala (m)",
    "Al-Maragha (m)",
    "El-Marg (k)",
    "El-Matariyya (k)",
    "El-Matariyya (m)",
    "Al-Muski (k)",
    "El-Nozha (k)",
    "El-Omraniya (k)",
    "Al-Qanater Al-Khayreya (m)",
    "Al-Qanayat (k)",
    "El-Qantara (m)",
    "El-Qantara Al-Sharqiya (k)",
    "El-Qoseir (k)",
    "El-Qurain (k)",
    "Al-Qusia (m)",
    "Al-Rahmaniyya (m)",
    "El-Raml 1 (k)",
    "El-Raml 2 (k)",
    "Al-Reyad (m)",
    "Al-Saff (m)",
    "Al-Salam (k)",
    "Al-Santa (m)",
    "Al-Sayeda Zeinab (k)",
    "El-Segil (k)",
    "Al-Senbellawein (m)",
    "El-Sharabiya (k)",
    "El-Sharq (k)",
    "El-Shohada (m)",
    "El-Shorouk (k)",
    "El-Tebbin (k)",
    "El-Tor (k)",
    "Al-Usayrat (m)",
    "Al-Wahat El-Bahariya (k)",
    "Al-Wahat El-Khariga (k)",
    "Al-Waqf (m)",
    "El-Warraq (k)",
    "Al-Wasta (m)",
    "El-Weili (k)",
    "El-Zaher (k)",
    "El-Zarqa (m)",
    "Al-Zawya El-Hamra (k)",
    "El-Zohur (k)",
    "Esna (m)",
    "Faysal (k)",
    "Fayyum (k)",
    "Fayyum City (m)",
    "Faqus (k)",
    "Faqus (m)",
    "Fariskur (m)",
    "Farshut (m)",
    "Fayid (m)",
    "Fuwwa (m)",
    "Gamsa (k)",
    "Al-Ganoub (k)",
    "Al-Ganoub 1 (k)",
    "Al-Ganoub 2 (k)",
    "Gharb Nubariya (k)",
    "Girga (k)",
    "Girga (m)",
    "Giza (k)",
    "Giza (m)",
    "Hada'iq Al-Qubba (k)",
    "Halayib (k)",
    "Heliopolis (k)",
    "Hilwan (k)",
    "Hihya (m)",
    "Hosh Essa (m)",
    "Hurghada 1 (k)",
    "Hurghada 2 (k)",
    "Ibsheway (m)",
    "Ihnasiya (m)",
    "Imbaba (k)",
    "Imbaba (m)",
    "Ismailiyya (m)",
    "Ismailiyya 1 (k)",
    "Ismailiyya 2 (k)",
    "Ismailiyya 3 (k)",
    "Itay Al-Barud (m)",
    "Itsa (m)",
    "Juhayna (m)",
    "Kafr Al-Dawwar (k)",
    "Kafr Al-Dawwar (m)",
    "Kafr Al-Shaykh (k)",
    "Kafr Al-Shaykh (m)",
    "Kafr Al-Zayyat (m)",
    "Kafr Sad (m)",
    "Kafr Saqr (m)",
    "Kafr Shukr (m)",
    "Karmuz (k)",
    "Kardasa (m)",
    "Khanka (m)",
    "Khsos (k)",
    "Kum Hamada (m)",
    "Kum Umbu (m)",
    "Kotoor (m)",
    "Luxor (k)",
    "Luxor (m)",
    "Maadi (k)",
    "Maghaghah (m)",
    "Mahallat Dimna (m)",
    "Mallawi (k)",
    "Mallawi (m)",
    "Manfalut (m)",
    "El Mansora (m)",
    "El Mansora 1 (k)",
    "E Mansora 2 (k)",
    "Marina El-Alamein (k)",
    "Marsa Alam (k)",
    "Mashtool El-Souk (m)",
    "Matay (m)",
    "Minuf (k)",
    "Minuf (m)",
    "Marsa Matruh (k)",
    "Metoubes (m)",
    "Minya (k)",
    "Minya (m)",
    "Minya al-Qamh (m)",
    "Minya Al-Nasr (m)",
    "Mit Ghamr (k)",
    "Mit Ghamr (m)",
    "Mit Salsil (m)",
    "Moharam Bek (k)",
    "Manshat Al-Nasr (k)",
    "Montaza (k)",
    "Mubarak East El-Tafrea (k)",
    "Nabaroh (m)",
    "Nag Hammadi (m)",
    "Nakhl (k)",
    "Naqada (m)",
    "Nasir Bush (m)",
    "Nasr (m)",
    "Nasr City (k)",
    "Nasr City 1 (k)",
    "Nasr City 2 (k)",
    "New Akhmim (n)",
    "New Aswan (n)",
    "New Asyut (n)",
    "New Beni Suef (k)",
    "New Borg El-Arab (n)",
    "New Cairo-1 (k)",
    "New Cairo-2 (k)",
    "New Cairo-3 (k)",
    "New Damietta (k)",
    "New Faiyum (n)",
    "New Minya (n)",
    "New Qena (n)",
    "New Salhia (k)",
    "New Sohag (n)",
    "New Toshka (n)",
    "North Coast (k)",
    "Nuweiba (k)",
    "Obour (k)",
    "Old Cairo (k)",
    "Port Fuad 1 (k)",
    "Port Fuad 2 (k)",
    "Suez Port Police Department (p)",
    "Qaha (k)",
    "Qillin (m)",
    "Qalyub (k)",
    "Qalyub (m)",
    "Qasr Al-Nile (k)",
    "Qina (k)",
    "Qina (m)",
    "Qift (m)",
    "Quwisna (m)",
    "Qus (m)",
    "Rafah (k)",
    "Ras al-Bar (k)",
    "Ras Gharib (k)",
    "Ras Sidr (k)",
    "Rud Al-Farag (k)",
    "Rosetta (m)",
    "Sadat City (m)",
    "Safaga (k)",
    "Sahil Salim (m)",
    "Sant Katrin (k)",
    "Salloum (k)",
    "Samalut (m)",
    "Samannud (m)",
    "Saqultah (m)",
    "Sirs Al-Layyana City (k)",
    "Shallatin (k)",
    "Sharm el-Sheikh (k)",
    "Shaykh Zayed (k)",
    "Shaykh Zuwayd (k)",
    "Shibin al-Kum (k)",
    "Shibin al-Kum (m)",
    "Shibin al-Qanatir (m)",
    "Shirbin (m)",
    "Shubra (k)",
    "Shubra Al-Khayma 1 (k)",
    "Shubra Al-Khayma 2 (k)",
    "Shubra Khît (m)",
    "Dakhla Oasis Police (m)",
    "Farafra Oasis Police (m)",
    "Qasima Police (k)",
    "Rummana Police (k)",
    "Sidfa (m)",
    "Sidi Barani (k)",
    "Sidi Gabir (k)",
    "Sidi Salim (m)",
    "Sinuras (m)",
    "Siwa (k)",
    "Suhag City (m)",
    "Suhag (m)",
    "Suhag1 (k)",
    "Suhag-2 (k)",
    "Suez (k)",
    "Suez Port Police Department (p)",
    "Sumusta As-Suq (m)",
    "Taba (k)",
    "Tahta (k)",
    "Tahta (m)",
    "Tala (m)",
    "Talkha (m)",
    "Tamya (m)",
    "Tanta (m)",
    "Tanta 1 (k)",
    "Tanta 2 (k)",
    "Tell El Kebir (m)",
    "Tiba police station (m)",
    "Tama (m)",
    "Tamy Al-Amdid (m)",
    "Tukh (m)",
    "Tura (k)",
    "Wadi Al-NatrUn (m)",
    "Yousef El sadeq (m)",
    "Zaqaziq (m)",
    "Zaqaziq 1 (k)",
    "Zaqaziq 2 (k)",
    "Zamalik (k)",
    "Zifta (m)",
    "Zeitoun (k)",
]

# %%
# Function to get the type of a municipal division
def get_municipal_division_type(municipal_divisions_name_EN):
    # Dictionary to hold the mapping of municipal division names to their types
    division_type_mapping = {}
    for item in list1:
        name, division_type = item.rsplit(" ", 1)
        division_type = division_type.strip("()")
        division_type_mapping[name] = division_type

    # Mapping the types to full form
    type_full_form = {
        'k': 'kism',
        'm': 'markaz',
        'n': 'new city',
        'p': 'police-administered'
    }
    
    # Check if the municipal division name is in the dictionary
    if municipal_divisions_name_EN in division_type_mapping:
        division_type = division_type_mapping[municipal_divisions_name_EN]
        return type_full_form.get(division_type, "Unknown type")
    else:
        return "Division not found"

# %%
# Replace with the path to your actual GeoJSON file
json_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/json/regions.json'
csv_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/csv/municipal_divisions.csv'
json_output_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/json/municipal_divisions_output.json'

# %%
try:
    with open(json_file_path, 'r') as file:
        data = json.load(file)
    
    csv_data = []
    for feature in data['features']:
        # Extract the first (exterior) ring of the polygon
        exterior_ring = feature['geometry']['coordinates'][0]
        
        # Pick a random point from the exterior ring
        if exterior_ring:  # Check if the exterior ring is not empty
            random_point = random.choice(exterior_ring)
            # Check if random_point is a list of lists
            if isinstance(random_point[0], list):
                random_point = random.choice(random_point)
            latitude, longitude = random_point[1], random_point[0]  # Assuming [longitude, latitude] order
        else:
            latitude, longitude = None, None
        
        csv_row = {
            'governorate_EN': feature['properties']['ADM1_EN'],
            'governorate_AR': feature['properties']['ADM1_AR'],
            'governorate_PCODE': feature['properties']['ADM1_PCODE'],
            'municipal_divisions_type': get_municipal_division_type(feature['properties']['ADM2_EN']),
            'municipal_divisions_name_EN': feature['properties'].get('ADM2_EN', ''), 
            'municipal_divisions_name_AR': feature['properties'].get('ADM2_AR', ''),
            'municipal_divisions_name_PCODE': feature['properties'].get('ADM2_PCODE', ''),
            "Country_EN": feature['properties']['ADM0_EN'],
            "Country_AR": feature['properties']['ADM0_AR'],
            "Country_PCODE": feature['properties']['ADM0_PCODE'],
            'latitude': latitude,
            'longitude': longitude
        }
        csv_data.append(csv_row)
    
    df = pd.DataFrame(csv_data)
    print(df.head())
    
    os.makedirs(os.path.dirname(csv_file_path), exist_ok=True)
    df.to_csv(csv_file_path, index=False, encoding='utf-8')
    print(f"Data successfully written to {csv_file_path}")
    
    with open(json_output_path, 'w', encoding='utf-8') as jsonfile:
        json.dump(csv_data, jsonfile, ensure_ascii=False, indent=4)
    print(f"Data successfully written to {json_output_path}")
    
except FileNotFoundError:
    print(f"The file {json_file_path} does not exist.")
except json.JSONDecodeError:
    print(f"The file {json_file_path} is not a valid JSON or GeoJSON file.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
get_municipal_division_type("10 Ramadan 1")

# %%
df.head()

# %%
# Assuming 'df' is your DataFrame and it already contains 'municipal_divisions_type' column

# Get all rows where municipal_divisions_type is 'Division not found' and print their municipal_divisions_name_EN
not_found_divisions = df.loc[df["municipal_divisions_type"] == "Division not found", "municipal_divisions_name_EN"]

# Print the result
print(not_found_divisions)

# %%
from random import choice, randint
import datetime

# Define lists for random selection
themes = ["R_C", "D_E", "E_E", "H_D", "P_S", "I_D"]
governorates = ["Alexandria", "Assiut", "Aswan", "Behera", "Beni Suef", "Cairo", "Dakahlia", "Damietta", 
                "Fayoum", "Gharbia", "Giza", "Ismailia", "Kafr El-Shikh", "Kalyoubia", "Luxor", "Matrouh", 
                "Menia", "Menoufia", "New Valley", "North Sinai", "Port Said", "Qena", "Red Sea", "Sharkia", 
                "South Sinai", "Suez", "Suhag"]
status_options = ["current", "completed", "pending"]

# Function to generate random dates
def random_date(start, end):
    return start + datetime.timedelta(days=randint(0, (end - start).days))

# Dummy data generator function
def generate_dummy_data(num_records=10):
    dummy_data = []
    start_date = datetime.date(2020, 1, 1)
    end_date = datetime.date(2025, 12, 31)
    
    for _ in range(num_records):
        project_no = randint(1, 1000)
        start = random_date(start_date, end_date - datetime.timedelta(days=365))  # Ensure start before end
        end = random_date(start + datetime.timedelta(days=1), end_date)  # End after start
        governorate = choice(governorates)
        
        data = {
            "id": f"ID{project_no}",
            "projectNo": project_no,
            "projectName": f"Project {project_no}",
            "projectDetail": f"Detail of project {project_no}",
            "photoURL": f"https://picsum.photos/250?image={randint(1, 100)}",
            "executingAgency": "Agency",
            "status": choice(status_options),
            "theme": [choice(themes)],
            "estimatedCost": randint(1000, 100000),
            "budget": randint(1000, 100000),
            "totalDonatedAmount": randint(1000, 100000),
            "startDate": start.isoformat(),
            "endDate": end.isoformat(),
            "Latitude": float(f"{randint(-90, 90)}.{randint(1, 999999)}"),
            "Longitude": float(f"{randint(-180, 180)}.{randint(1, 999999)}"),
            "City_Name_EN": "City",
            "City_Name_AR": "مدينة",
            "City_Name_PCODE": "",
            "City_PCODE": "",
            "State_Name_EN": "State",
            "State_Name_AR": "حالة",
            "State_Name_PCODE": "",
            "Region_Name_EN": "Region",
            "Region_Name_AR": "منطقة",
            "Region_PCODE": "",
            "Locality_Name_EN": "Locality",
            "Locality_Name_AR": "محلية",
            "Locality_PCODE": "",
            "Province_Name_EN": "Province",
            "Province_Name_AR": "محافظة",
            "Province_PCODE": "",
            "municipal_divisions_type": "",
            "municipal_divisions_name_EN": "",
            "municipal_divisions_name_AR": "",
            "municipal_divisions_name_PCODE": "",
            "Governorate_Name_EN": governorate,
            "Governorate_Name_AR": "محافظة",
            "Governorate_PCODE": "",
            "District_Name_EN": "District",
            "District_Name_AR": "منطقة",
            "District_PCODE": "",
            "Country_EN": "Country",
            "Country_AR": "بلد",
            "Country_PCODE": "",
            "donor": "Donor",
            "contribution": "Contribution",
            "dataReliability": "High"
        }
        dummy_data.append(data)
    
    return dummy_data

# Generate 10 dummy records
dummy_data = generate_dummy_data(10)
dummy_data[:2]  # Display first two records to check

# %%
import chardet
import pandas as pd
import json
import ast

# %%
# Define the CSV input and JSON output file names
csv_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/csv/trial2.csv'
json_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/json/project_data.json'

# %%
# Open the file in binary mode and read a portion to detect its encoding
with open(csv_file_path, 'rb') as file:
    result = chardet.detect(file.read(10000))  # Reading the first 10000 bytes

# Extract the encoding
encoding = result['encoding']
print("Detected encoding:", encoding)

# %%
executingAgency = [
    {
        "executingAgencyName": "UNDP",
        "executingAgencyDepartment": "Accelerator Lab",
        "executingAgencyTeam": "Exploration Team",
        "executingAgencyEmail": "undp@undp.org",
        "executingAgencyWebsite": "https://www.undp.org",
        "executingAgencyPhotoUrl": "data:image/png;base64,[image_data]",
        "executingAgencyProjectList": ["Project1", "Project2", "Project3"]
    }
]

donors = [
    {
        "donorName": "Donor1 name",
        "donorEmail": "email@undp.org",
        "donorWebsite": "https://www.undp.org",
        "donorPhotoUrl": "data:image/png;base64,[image_data]",
        "donorProjectList": ["Project1", "Project2", "Project3"],
        "donationAmount": 2500
    },
    {
        "donorName": "Donor2 name",
        "donorEmail": "email@undp.org",
        "donorWebsite": "https://www.undp.org",
        "donorPhotoUrl": "data:image/png;base64,[image_data]",
        "donorProjectList": ["Project1", "Project2", "Project3"],
        "donationAmount": 2500
    },
    {
        "donorName": "Donor3 name",
        "donorEmail": "email@undp.org",
        "donorWebsite": "https://www.undp.org",
        "donorPhotoUrl": "data:image/png;base64,[image_data]",
        "donorProjectList": ["Project1", "Project2", "Project3"],
        "donationAmount": 2500
    },
    {
        "donorName": "Donor4 name",
        "donorEmail": "email@undp.org",
        "donorWebsite": "https://www.undp.org",
        "donorPhotoUrl": "data:image/png;base64,[image_data]",
        "donorProjectList": ["UNDP Data Bank", "Project1", "Project2", "Project3"],
        "donationAmount": 2500
    }
]

contribution = "contribution"
dataReliability = "dataReliability"

# %%
# Detect the encoding of the CSV file
with open(csv_file_path, 'rb') as file:
    encoding = chardet.detect(file.read(10000))['encoding']


# Read the CSV file into a pandas DataFrame using the detected encoding
df["executingAgency"] = [executingAgency[0]] * len(df)
df["donor"] = [donors[i % len(donors)] for i in range(len(df))]

df["contribution"] = contribution
df["dataReliability"] = dataReliability


df.head()

# Convert the DataFrame to a list of dictionaries
data = df.to_dict(orient='records')

# Write the data to a JSON file
with open(json_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, indent=4, ensure_ascii=False)

print(f"CSV data has been successfully converted to JSON and saved to '{json_file_path}'")

# %%
import json
import pandas as pd
import os

def process_features(features):
    processed_features = []
    id_counter = 1  # Initialize a counter for assigning IDs
    
    for feature in features:
        geometry = feature.get('geometry', {})
        properties = feature.get('properties', {})
        
        # Determine if the feature is a governorate or a municipal division
        feature_type = 'Governorate' if 'Governorate' in properties.get('ADM1_EN', '') else 'MunicipalDivision'
        feature_id = id_counter
        id_counter += 1  # Increment the ID counter for the next feature

        # Initialize coordinates as None
        coordinates = None
        
        # Check if geometry type is Polygon or MultiPolygon and convert to Point
        coordinates = geometry
        # if geometry['type'] in ['Polygon', 'MultiPolygon'] and geometry['coordinates']:
        #     coords = geometry['coordinates'][0][0]  # Use the first point of the first linear ring
        #     if coords and isinstance(coords, list):
        #         # Convert Polygon to Point by selecting the first point (as an example)
        #         coordinates = { "type": "Point", "coordinates": [coords[0], coords[1]] }
        
        processed_feature = {
            'ID': feature_id,
            'Type': feature_type,
            'Governorate_Name_EN': properties.get('ADM1_EN', ''),
            'Governorate_Name_AR': properties.get('ADM1_AR', ''),
            'Governorate_PCODE': properties.get('ADM1_PCODE', ''),
            'Country_EN': properties.get('ADM0_EN', ''),
            'Country_AR': properties.get('ADM0_AR', ''),
            'Country_PCODE': properties.get('ADM0_PCODE', ''),
            # 'Coordinates': coordinates,
        }
        
        # Only include municipal division details if ADM2 fields are present
        if 'ADM2_EN' in properties:
            processed_feature.update({
                'Municipal_Division_Type': None,
                'Municipal_Division_Name_EN': properties.get('ADM2_EN', ''),
                'Municipal_Division_Name_AR': properties.get('ADM2_AR', ''),
                'Municipal_Division_PCODE': properties.get('ADM2_PCODE', ''),
            })
        
        processed_features.append(processed_feature)
    
    return processed_features

def extract_data_from_json(json_file_path, csv_file_path, json_output_path):
    try:
        with open(json_file_path, 'r') as file:
            data = json.load(file)
        
        features = data.get('features', [])
        processed_features = process_features(features)
        
        # Convert to DataFrame for CSV output
        df = pd.DataFrame(processed_features)
        df.to_csv(csv_file_path, index=False, encoding='utf-8')
        print(f"Data successfully written to {csv_file_path}")
        
        # Output to JSON file
        with open(json_output_path, 'w', encoding='utf-8') as jsonfile:
            json.dump(processed_features, jsonfile, ensure_ascii=False, indent=4)
        print(f"Data successfully written to {json_output_path}")
        
    except FileNotFoundError:
        print(f"The file {json_file_path} does not exist.")
    except json.JSONDecodeError:
        print(f"The file {json_file_path} is not a valid JSON or GeoJSON file.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
# Placeholder path to your JSON file
json_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/json/governorates.json'
csv_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/csv/interventions_governorate_map.csv'
json_output_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/json/interventions_governorate_map.json'
extract_data_from_json(json_file_path, csv_file_path, json_output_path)

# %%
# Placeholder path to your JSON file
json_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/json/municipal_divisions.json'
csv_file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/csv/interventions_municipal_division_map.csv'
json_output_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt_horizon_scanner_frontend/assets/json/interventions_municipal_division_map.json'
extract_data_from_json(json_file_path, csv_file_path, json_output_path)

# %%
import json

# Specify the path to your JSON file
file_path = '/Users/izzymohamed/Desktop/Horizon Scanner/egypt-horizon-scanner/JSON/Response Now/Interventions Mapping/interventions_municipal_division_map copy.json'

# Read the JSON data from the file
with open(file_path, 'r') as file:
    data = json.load(file)

# Remove the 'Coordinates' key from each item in the JSON data if it exists
if isinstance(data, list):  # If the data is a list of dictionaries
    for item in data:
        item.pop('Coordinates', None)
elif isinstance(data, dict):  # If the data is a single dictionary
    data.pop('Coordinates', None)

# Save the modified data back to the same JSON file
with open(file_path, 'w') as file:
    json.dump(data, file, indent=4)

print("Coordinates key has been removed and the file has been updated.")

# %%
import json

# Read the JSON file
with open("/Users/izzymohamed/Desktop/Horizon Scanner/egypt-horizon-scanner/JSON/Digital Avatar/Dimensions.json", 'r') as file:
    data = json.load(file)
    
    # Convert "Data Visualization" from string to list of strings
    for item in data:
        if "Data Visualization" in item:
            visualization = item["Data Visualization"]
            if visualization and visualization.lower() not in ["none", "null"]:
                split_visualization = []
                for v in visualization.split(", "):
                    split_visualization.extend([x.strip() for x in v.split("and ")])
                    split_visualization.extend([x.strip() for x in v.split("or ")])
                # Remove duplicates
                item["Data Visualization"] = list(set(split_visualization))

# Save the modified data back to the JSON file
# output_file_path = "/Users/izzymohamed/Desktop/Horizon Scanner/egypt-horizon-scanner/JSON/Digital Avatar/Modified_Dimensions.json"
# with open(output_file_path, 'w') as output_file:
#     json.dump(data, output_file, indent=4)

# print("Modified JSON data has been saved to:", output_file_path)

# %%
# Example usage
descriptions = [
    "I love this product, it works great!",
    "The movie was terrible and boring.",
    "This is a neutral statement about weather.",
    "What a wonderful day to have a picnic!",
    "I am disappointed with the service."
]

# %%
from transformers import pipeline, TFAutoModelForSequenceClassification, AutoTokenizer
import tensorflow as tf

# Define the model name
model_name = "jysh1023/tiny-bert-sst2-distilled"

# Load the sentiment analysis pipeline
sentiment_analysis_model = pipeline("sentiment-analysis", model=model_name)
text_classifier = pipeline("text-classification", model=model_name)

# Load the model and tokenizer for custom function
model = TFAutoModelForSequenceClassification.from_pretrained(model_name, from_pt=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
def sentiment_analysis(text, model, tokenizer, pipeline):
    # Encode the text using the tokenizer
    inputs = tokenizer(text, return_tensors="tf", truncation=True, padding=True, max_length=512)

    # Perform the prediction
    outputs = mongoose.modelinputs)

    # Apply softmax to convert logits to probabilities
    probabilities = tf.nn.softmax(outputs[0], axis=-1)

    # Get the predicted class (index with the highest probability)
    predicted_class_index = tf.argmax(probabilities, axis=-1).numpy()[0]
    
    # Mapping labels to more readable form
    label_map = {0: "Negative", 1: "Positive"}  # Update this map based on your model.js's training
    predicted_class = label_map[predicted_class_index]

    return predicted_class, probabilities.numpy()

# %%
for description in descriptions:
    # Perform sentiment analysis
    sentiment, probabilities = sentiment_analysis(description, model, tokenizer, text_classifier)
    print(f"Text: {description}")
    print(f"Classification: {sentiment}")
    print("-" * 60)

# %%
from transformers import pipeline

# Classify the texts and print the results
results = text_classifier(descriptions)

for text, result in zip(descriptions, results):
    print(f"Text: {text}")
    print(f"Classification: {result['label']}, Score: {result['score']:.4f}")
    print("-" * 60)

# %%
emerging_issues = [
    "Water Issue", "Climate Change", "Food Security", "Health Crisis", "Economic Recession",
    "Energy Crisis", "Biodiversity Loss", "Political Instability", "Education Gap", "Technological Disruption",
    "Housing Shortage", "Transportation Problems", "Waste Management", "Cultural Decline", "Social Inequality"
]

# %%
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset
import torch

# Define a function to tokenize the data
def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True)

# Load the tokenizer
tokenizer = BertTokenizer.from_pretrained(model_name)

# Assume 'my_dataset' is already loaded with the format [{'text': 'example text', 'label': 0}, ...]
dataset = load_dataset('csv', data_files='path_to_your_data.csv')
dataset = dataset.map(tokenize_function, batched=True)

# Define the model
model = BertForSequenceClassification.from_pretrained(model_name, num_labels=len(emerging_issues))

# Training arguments
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=3,              # number of training epochs
    per_device_train_batch_size=8,   # batch size for training
    per_device_eval_batch_size=16,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    logging_steps=10,
)

# Initialize the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset['train'],
    eval_dataset=dataset['test']
)

# Train the model
trainer.train()

# %%
from pymongo import MongoClient
import pandas as pd

mongo_uri = 'mongodb+srv://doadmin:73Le6F4d2hZ9K8Y0@dbaas-db-5626135-310aba91.mongo.ondigitalocean.com/egypt-horizon-scanner?replicaSet=dbaas-db-5626135&tls=true&authSource=admin'
client = MongoClient(mongo_uri)
db = client["egypt-horizon-scanner"]
collection = db["emergence_issue_of_the_month_data"]

# Read data from MongoDB collection into a DataFrame
data = pd.DataFrame(list(collection.find()))

# %%
# Group by emergingIssue
grouped_data = data.groupby('emergingIssue').size().reset_index(name='count')

issues_dic = {}

# save the each grouped data into its own df
for issue in grouped_data['emergingIssue']:
    issue_df = data[data['emergingIssue'] == issue]
    issues_dic[issue] = issue_df

# %%
issues_dic
# Out:
# {'Biodiversity Loss':                            _id    Id      emergingIssue  \
#  17    663599651e65fd9ca3aea280    18  Biodiversity Loss
#  27    663599651e65fd9ca3aea28a    28  Biodiversity Loss
#  46    663599651e65fd9ca3aea29d    47  Biodiversity Loss
#  60    663599651e65fd9ca3aea2ab    61  Biodiversity Loss
#  84    663599651e65fd9ca3aea2c3    85  Biodiversity Loss
#  ...                        ...   ...                ...
#  2858  663599651e65fd9ca3aead99  2859  Biodiversity Loss
#  2861  663599651e65fd9ca3aead9c  2862  Biodiversity Loss
#  2865  663599651e65fd9ca3aeada0  2866  Biodiversity Loss
#  2908  663599651e65fd9ca3aeadcb  2909  Biodiversity Loss
#  2921  663599651e65fd9ca3aeadd8  2922  Biodiversity Loss
#
#                            issueTitle  \
#  17        Coastal Erosion Mitigation
#  27    Affordable Housing Initiatives
#  46        Traffic Management Systems
#  60              Food Reserve Systems
#  84               Habitat Destruction
#  ...                              ...
#  2858     Tourism Promotion Campaigns
#  2861               Electoral Reforms
#  2865           Vaccination Campaigns
#  2908     Renewable Energy Shortfalls
#  2921      Public Awareness Campaigns
#
#                                              description      source  \
#  17    Tourism promotion campaigns have had negative ...         FAQ
#  27    Telemedicine initiatives struggle with technol...         FAQ
#  46    Agricultural education programs are outdated a...         FAQ
#  60    SME support programs in Egypt are marred by bu...         FAQ
#  84    Urban greening initiatives are insufficient, w...         FAQ
#  ...                                                 ...         ...
#  2858  Subsidies for local farmers are mismanaged, le...  World Bank
#  2861  Traffic management systems have failed to alle...  World Bank
#  2865  Renewable energy development in Egypt has been...  World Bank
#  2908  Vaccination campaigns in Egypt face challenges...  World Bank
#  2921  Housing projects remain incomplete, exacerbati...  World Bank
#
#                                              sdgTargeted sentimentAnalysis  \
#
#  4           Telemedicine Initiatives
#  7           Telemedicine Initiatives
#  54              Nile River Pollution
#  57        Traffic Management Systems
#  59       Climate Adaptation Policies
#  ...                              ...
#  2823               Electoral Reforms
#  2903            Nile River Pollution
#  2954          Mental Health Services
#  2969          Mental Health Services
#  2973  Cultural Preservation Policies
#
#                                              description      source  \
#  4     The expansion of rural healthcare is hindered ...         FAQ
#  7     Waste management policies are ineffective, wit...         FAQ
#  54    Vaccination campaigns have been hindered by mi...         FAQ
#  57    Subsidies for local farmers in Egypt have been...         FAQ
#  59    Public transportation upgrades lag, leading to...         FAQ
#  ...                                                 ...         ...
#  2823  Public awareness campaigns on climate change i...  World Bank
#  2903  SME support programs in Egypt are marred by bu...  World Bank
#  2954  Air quality worsens as emissions regulations a...  World Bank
#  2969  Water scarcity in Egypt has been worsened by i...  World Bank
#  2973  Agricultural education programs in Egypt suffe...  World Bank
#
#                                              sdgTargeted sentimentAnalysis  \
#  4     [GOAL 10: Reduced Inequality, GOAL 2: Zero Hun...          negative
#  7     [GOAL 11: Sustainable Cities And Communities, ...          negative
#  54                              [GOAL 15: Life on Land]          negative
#  57    [GOAL 11: Sustainable Cities And Communities, ...          negative
#  59    [GOAL 11: Sustainable Cities And Communities, ...          negative
#  ...                                                 ...               ...
#  2823  [GOAL 12: Responsible Consumption And Production]          negative
#  2903                          [GOAL 5: Gender Equality]          negative
#  2954  [GOAL 1: No Poverty, GOAL 3: Good Health And W...          negative
#  2969  [GOAL 6: Clean Water And Sanitation, GOAL 2: Z...          negative
#  2973  [GOAL 3: Good Health And Well-being, GOAL 8: D...          negative
#
#        weight     score language
#  4        0.5  0.830920  English
#  7        0.5  0.658701  English
#  54       0.5  0.801950  English
#  57       0.5  0.677598  English
#  59       0.5  0.707091  English
#  ...      ...       ...      ...
#  2823     0.5  0.718028  English
#  2903     0.5  0.719668  English
#  2954     0.5  0.885125  English
#  2969     0.5  0.824502  English
#  2973     0.5  0.636911  English
#
#  [220 rows x 11 columns],
#  'Food Security':                            _id    Id  emergingIssue  \
#  10    663599651e65fd9ca3aea279    11  Food Security
#  20    663599651e65fd9ca3aea283    21  Food Security
#  38    663599651e65fd9ca3aea295    39  Food Security
#  63    663599651e65fd9ca3aea2ae    64  Food Security
#  78    663599651e65fd9ca3aea2bd    79  Food Security
#  ...                        ...   ...            ...
#  2925  663599651e65fd9ca3aeaddc  2926  Food Security
#  2962  663599651e65fd9ca3aeae01  2963  Food Security
#  2970  663599651e65fd9ca3aeae09  2971  Food Security
#  2985  663599651e65fd9ca3aeae18  2986  Food Security
#  2996  663599651e65fd9ca3aeae23  2997  Food Security
#
#                            issueTitle  \
#  10              Food Reserve Systems
#  20                 Electoral Reforms
#  38        Urban Greening Initiatives
#  63          Rural Education Barriers
#  78       Tourism Promotion Campaigns
#  ...                              ...
#  2925  Wildlife Conservation Programs
#  2962     Subsidies for Local Farmers
#  2970             AI in the Workforce
#  2985                Income Disparity
#  2996        Rural Education Barriers
#
#                                              description      source  \
#  10    Policies to significantly reduce industrial wa...         FAQ
#  20    Investments in agricultural technology are bia...         FAQ
  World Bank
#
#                                              sdgTargeted sentimentAnalysis  \
#  11    [GOAL 16: Peace And Justice Strong Institution...          negative
#  26    [GOAL 3: Good Health And Well-being, GOAL 1: N...          negative
#  40    [GOAL 11: Sustainable Cities And Communities, ...          negative
#  68    [GOAL 10: Reduced Inequality, GOAL 4: Quality ...          negative
#  76    [GOAL 9: Industry, Innovation And Infrastructu...          negative
#  ...                                                 ...               ...
#  2951               [GOAL 3: Good Health And Well-being]          negative
#  2955  [GOAL 10: Reduced Inequality, GOAL 9: Industry...          negative
#  2965  [GOAL 12: Responsible Consumption And Producti...          positive
#  2967  [GOAL 7: Affordable And Clean Energy, GOAL 9: ...          negative
#  2987  [GOAL 1: No Poverty, GOAL 15: Life on Land, GO...          negative
#
#        weight     score language
#  11       0.5  0.589552  English
#  26       0.5  0.762981  English
#  40       0.5  0.457882  English
#  68       0.5  0.760619  English
#  76       0.5  0.514964  English
#  ...      ...       ...      ...
#  2951     0.5  0.677598  English
#  2955     0.5  0.563323  English
#  2965     1.0  0.682005  English
#  2967     0.5  0.874196  English
#  2987     0.5  0.732208  English
#
#  [191 rows x 11 columns],
#  'Housing Shortage':                            _id    Id     emergingIssue  \
#  1     663599651e65fd9ca3aea270     2  Housing Shortage
#  22    663599651e65fd9ca3aea285    23  Housing Shortage
#  23    663599651e65fd9ca3aea286    24  Housing Shortage
#  35    663599651e65fd9ca3aea292    36  Housing Shortage
#  41    663599651e65fd9ca3aea298    42  Housing Shortage
#  ...                        ...   ...               ...
#  2966  663599651e65fd9ca3aeae05  2967  Housing Shortage
#  2975  663599651e65fd9ca3aeae0e  2976  Housing Shortage
#  2994  663599651e65fd9ca3aeae21  2995  Housing Shortage
#  2995  663599651e65fd9ca3aeae22  2996  Housing Shortage
#  2997  663599651e65fd9ca3aeae24  2998  Housing Shortage
#
#                        issueTitle  \
#  1     Industrial Waste Reduction
#  22     Regulation of Water Usage
#  23             Electoral Reforms
#  35             Electoral Reforms
#  41     Regulation of Water Usage
#  ...                          ...
#  2966  Digital Literacy Campaigns
#  2975  Industrial Waste Reduction
#  2994          Urban Overcrowding
#  2995  Public Awareness Campaigns
#  2997  Industrial Waste Reduction
#
#                                              description      source  \
#  1     Coastal erosion mitigation efforts fall short,...         FAQ
#  22    Educational reforms fail to close the gap, lea...         FAQ
#  23    Agricultural education programs are outdated a...         FAQ
#  35    Digital literacy campaigns in Egypt struggle t...         FAQ
#  41    Inflation control measures are ineffective, le...         FAQ
#  ...                                                 ...         ...
#  2966  Social welfare programs are slashed, leaving t...  World Bank
#  2975  Regulation of water usage in Egypt has been un...  World Bank
#  2994  AI in the workforce threatens to exacerbate un...  World Bank
#  2995  Offshore wind farms in Egypt face opposition f...  World Bank
#  2997  Telemedicine initiatives in Egypt struggle to ...  World Bank
#
#                                              sdgTargeted sentimentAnalysis  \
#
#  101   Cultural Preservation Policies
#  130               Urban Overcrowding
#  ...                              ...
#  2960         Public Transit Upgrades
#  2978      Industrial Waste Reduction
#  2982         Governmental Corruption
#  2984     Climate Adaptation Policies
#  2986        Rural Education Barriers
#
#                                              description      source  \
#  33    Efforts to mitigate coastal erosion in Egypt f...         FAQ
#  74    Urban overcrowding in Egypt strains public ser...         FAQ
#  99    Efforts to mitigate coastal erosion in Egypt h...         FAQ
#  101   Expansion of rural healthcare has been stalled...         FAQ
#  130   Artificial intelligence development leads to u...         FAQ
#  ...                                                 ...         ...
#  2960  Habitat destruction in Egypt threatens iconic ...  World Bank
#  2978  Subsidies for local farmers are mismanaged, le...  World Bank
#  2982  Traffic management systems have failed to alle...  World Bank
#  2984  Water scarcity in Egypt has been exacerbated b...  World Bank
#  2986  Subsidies for local farmers in Egypt have been...  World Bank
#
#                                              sdgTargeted sentimentAnalysis  \
#  33        [GOAL 11: Sustainable Cities And Communities]          negative
#  74    [GOAL 13: Climate Action, GOAL 2: Zero Hunger,...          negative
#  99     [GOAL 16: Peace And Justice Strong Institutions]          negative
#  101   [GOAL 12: Responsible Consumption And Producti...          negative
#  130   [GOAL 8: Decent Work And Economic Growth, GOAL...          negative
#  ...                                                 ...               ...
#  2960                            [GOAL 15: Life on Land]          negative
#  2978                        [GOAL 4: Quality Education]          negative
#  2982  [GOAL 13: Climate Action, GOAL 2: Zero Hunger,...          negative
#  2984  [GOAL 5: Gender Equality, GOAL 3: Good Health ...          negative
#  2986  [GOAL 6: Clean Water And Sanitation, GOAL 9: I...          negative
#
#        weight     score language
#  33       0.5  0.781469  English
#  74       0.5  0.816911  English
#  99       0.5  0.701771  English
#  101      0.5  0.634969  English
#  130      0.5  0.676752  English
#  ...      ...       ...      ...
#  2960     0.5  0.780800  English
#  2978     0.5  0.764575  English
#  2982     0.5  0.534800  English
#  2984     0.5  0.698302  English
#  2986     0.5  0.677598  English
#
#  [189 rows x 11 columns],
#  'Water Issue':                            _id    Id emergingIssue  \
#  12    663599651e65fd9ca3aea27b    13   Water Issue
#  16    663599651e65fd9ca3aea27f    17   Water Issue
#  43    663599651e65fd9ca3aea29a    44   Water Issue
#  87    663599651e65fd9ca3aea2c6    88   Water Issue
#  95    663599651e65fd9ca3aea2ce    96   Water Issue
#  ...                        ...   ...           ...
#  2971  663599651e65fd9ca3aeae0a  2972   Water Issue
#  2977  663599651e65fd9ca3aeae10  2978   Water Issue
#  2988  663599651e65fd9ca3aeae1b  2989   Water Issue
#  2991  663599651e65fd9ca3aeae1e  2992   Water Issue
#  2993  663599651e65fd9ca3aeae20  2994   Water Issue
#
#                            issueTitle  \
#  12        Industrial Waste Reduction
#  16          Telemedicine Initiatives
#  43          Rural Education Barriers
#  87              Nile River Pollution
#  95    Affordable Housing Initiatives
#  ...                              ...
#  2971        Foreign Trade Agreements
#  2977        Rural Education Barriers
#  2988      Public Awareness Campaigns
#  2991            Food Reserve Systems
#  2993            Food Reserve Systems
#
#                                              description      source  \
#  12    Tourism promotion campaigns have had negative ...         FAQ
#  16    Agricultural technology investments in Egypt h...         FAQ
#  43    Offshore wind farms in Egypt face opposition f...         FAQ
#  87    Tourism promotion campaigns in Egypt often pri...         FAQ
#  95    Public awareness campaigns on climate change i...         FAQ
#  ...                                                 ...         ...
#  2971  Vaccination campaigns are met with skepticism ...  World Bank
#  2977  Regulations on water usage are often flouted, ...  World Bank
#  2988  Public awareness campaigns on climate change h...  World Bank
#  2991  Income disparity in Egypt is widening, leading...  World Bank
#  2993  Climate adaptation policies are underfunded an...  World Bank
#
#                                              sdgTargeted sentimentAnalysis  \
#  12    [GOAL 12: Responsible Consumption And Producti...          negative
#  16    [GOAL 6: Clean Water And Sanitation, GOAL 14: ...          positive
#  43     [GOAL 16: Peace And Justice Strong Institutions]          negative
#  87    [GOAL 14: Life Below Water, GOAL 4: Quality Ed...          positive
#  95    [GOAL 13: Climate Action, GOAL 2: Zero Hunger,...          negative
#  ...                                                 ...               ...
#  2971  [GOAL 10: Reduced Inequality, GOAL 2: Zero Hun...          negative
#  2977  [GOAL 7: Affordable And Clean Energy, GOAL 11:...          negative
#  2988  [GOAL 1: No Poverty, GOAL 7: Affordable And Cl...          negative
#  2991        [GOAL 17: Partnerships to achieve the Goal]          negative
#  2993  [GOAL 11: Sustainable Cities And Communities, ...          negative
#
#        weight     score language
#  12       0.5  0.760619  English
#  16       1.0  0.770081  English
#  43       0.5  0.687919  English
#  87       1.0  0.489958  English
#  95       0.5  0.557550  English
#  ...      ...       ...      ...
#  2971     0.5  0.836336  English
#  2977     0.5  0.643975  English
#  2988     0.5  0.595832  English
#  2991     0.5  0.766289  English
#  2993     0.5  0.787977  English
#
#  [202 rows x 11 columns]}

# %%
import pandas as pd
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM

# Initialize tokenizer and model
model_name = "sshleifer/distilbart-cnn-12-6"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Counting the total number of parameters
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total trainable parameters in {model_name}: {total_params}")

# Load a pre-trained model for summarization using the pipeline
summarizer = pipeline("summarization", model=model, tokenizer=tokenizer)

def generate_summary(text, model, tokenizer):
    # Check the length of tokenized input
    inputs = tokenizer.encode(text, return_tensors="pt", truncation=True, max_length=1024)
    # Generate summary
    summary_ids = model.generate(inputs, max_length=300, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary
# Out:
# Total trainable parameters in facebook/bart-large-cnn: 406290432

# %%
for category, df in issues_dic.items():
    print(f"Category: {category}")
    # Combine all descriptions into one text for summarization
    combined_text = ' '.join(df['description'].tolist())
    print(f"Combined Text:\n{combined_text}")
    # Generate and print the summary paragraph
    summary_paragraph = generate_summary(combined_text, model, tokenizer)
    print(f"Summary Paragraph:\n{summary_paragraph}")
    print("-" * 300)
# Out:
# Category: Biodiversity Loss
# Combined Text:
# Tourism promotion campaigns have had negative environmental impacts. Telemedicine initiatives struggle with technological disparities and lack of accessibility in remote areas. Agricultural education programs are outdated and fail to equip farmers with the skills needed for modern farming. SME support programs in Egypt are marred by bureaucratic hurdles and favoritism. Urban greening initiatives are insufficient, with cities remaining heat islands with poor air quality. Subsidies for local farmers are mismanaged, leading to market distortions and inefficiencies in food production. Policies to significantly reduce industrial waste through better practices and recycling technologies. Mental health services are severely underfunded and stigmatized, leaving many without necessary support. Subsidies for local farmers have been disproportionately allocated, favoring wealthier regions. Issues of corruption and lack of transparency leading to widespread dissatisfaction and protests. Mental health services are severely underfunded and stigmatized, leaving many without necessary support.
Urban greening initiatives are insufficient, with cities remaining heat islands with poor air quality. Inflation control measures are ineffective, leading to continued economic hardship for the middle and lower classes. Significant loss of natural habitats leading to a decrease in wildlife populations and biodiversity. Urban greening initiatives are insufficient, with cities remaining heat islands with poor air quality. Water treatment facilities are overwhelmed, leading to unsafe drinking water and increased public health risks. The expansion of rural healthcare is hindered by inadequate funding and lack of skilled healthcare professionals. Governmental efforts to preserve and promote cultural heritage amid fears of cultural decline. Climate adaptation policies in Egypt lack coordination between government agencies and local communities. Traffic management systems in Egypt are overwhelmed by congestion and lack of public transportation options. Launching nationwide digital literacy campaigns to bridge the education gap in technology use and access. Housing pro ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 7
#       5 print(f"Combined Text:\n{combined_text}")
#       6 # Generate and print the summary paragraph
# ----> 7 summary_paragraph = generate_summary(combined_text, model, tokenizer)
#       8 print(f"Summary Paragraph:\n{summary_paragraph}")
#       9 print("-" * 300)
#
# Cell In[84], line 21, in generate_summary(text, model, tokenizer)
#      19 inputs = tokenizer.encode(text, return_tensors="pt", truncation=True, max_length=1024)
#      20 # Generate summary
# ---> 21 summary_ids = model.generate(inputs, max_length=300, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
#      22 summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#      23 return summary
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/generation/utils.py:1655, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1648     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1649         input_ids=input_ids,
#    1650         expand_size=generation_config.num_beams,
#    1651         is_encoder_decoder=self.config.is_encoder_decoder,
#    1652         **model_kwargs,
#    1653     )
#    1654     # 13. run beam search
# -> 1655     result = self._beam_search(
#    1656         input_ids,
#    1657         beam_scorer,
#    1658         logits_processor=prepared_logits_processor,
#    1659         stopping_criteria=prepared_stopping_criteria,
#    1660         pad_token_id=generation_config.pad_token_id,
#    1661         output_scores=generation_config.output_scores,
#    1662         output_logits=generation_config.output_logits,
#    1663         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1664         synced_gpus=synced_gpus,
#    1665         sequential=generation_config.low_memory,
#    1666         **model_kwargs,
#    1667     )
#    1669 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1670     # 11. prepare logits warper
#    1671     logits_warper = self._get_logits_warper(generation_config)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/generation/utils.py:3171, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, sequential, **model_kwargs)
#    3168     outputs = stack_model_outputs(outputs_per_sub_batch)
#    3170 else:  # Unchanged original behavior
# -> 3171     outputs = self(
#    3172         **model_inputs,
#    3173         return_dict=True,
#    3174         output_attentions=output_attentions,
#    3175         output_hidden_states=output_hidden_states,
#    3176     )
#    3178 if synced_gpus and this_peer_finished:
#    3179     cur_len = cur_len + 1
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:1728, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1723     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1724         decoder_input_ids = shift_tokens_right(
#    1725             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1726         )
# -> 1728 outputs = self.model(
#    1729     input_ids,
#    1730     attention_mask=attention_mask,
#    1731     decoder_input_ids=decoder_input_ids,
#    1732     encoder_outputs=encoder_outputs,
#    1733     decoder_attention_mask=decoder_attention_mask,
#    1734     head_mask=head_mask,
#    1735     decoder_head_mask=decoder_head_mask,
#    1736     cross_attn_head_mask=cross_attn_head_mask,
#    1737     past_key_values=past_key_values,
#    1738     inputs_embeds=inputs_embeds,
#    1739     decoder_inputs_embeds=decoder_inputs_embeds,
#    1740     use_cache=use_cache,
#    1741     output_attentions=output_attentions,
#    1742     output_hidden_states=output_hidden_states,
#    1743     return_dict=return_dict,
#    1744 )
#    1746 lm_logits = self.lm_head(outputs[0])
#    1747 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:1614, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1607     encoder_outputs = BaseModelOutput(
#    1608         last_hidden_state=encoder_outputs[0],
#    1609         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1610         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1611     )
#    1613 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1614 decoder_outputs = self.decoder(
#    1615     input_ids=decoder_input_ids,
#    1616     attention_mask=decoder_attention_mask,
#    1617     encoder_hidden_states=encoder_outputs[0],
#    1618     encoder_attention_mask=attention_mask,
#    1619     head_mask=decoder_head_mask,
#    1620     cross_attn_head_mask=cross_attn_head_mask,
#    1621     past_key_values=past_key_values,
#    1622     inputs_embeds=decoder_inputs_embeds,
#    1623     use_cache=use_cache,
#    1624     output_attentions=output_attentions,
#    1625     output_hidden_states=output_hidden_states,
#    1626     return_dict=return_dict,
#    1627 )
#    1629 if not return_dict:
#    1630     return decoder_outputs + encoder_outputs
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:1467, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1454     layer_outputs = self._gradient_checkpointing_func(
#    1455         decoder_layer.__call__,
#    1456         hidden_states,
#    (...)
#    1464         use_cache,
#    1465     )
#    1466 else:
# -> 1467     layer_outputs = decoder_layer(
#    1468         hidden_states,
#    1469         attention_mask=attention_mask,
#    1470         encoder_hidden_states=encoder_hidden_states,
#    1471         encoder_attention_mask=encoder_attention_mask,
#    1472         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1473         cross_attn_layer_head_mask=(
#    1474             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1475         ),
#    1476         past_key_value=past_key_value,
#    1477         output_attentions=output_attentions,
#    1478         use_cache=use_cache,
#    1479     )
#    1480 hidden_states = layer_outputs[0]
#    1482 if use_cache:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:776, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     774 # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     775 cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 776 hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     777     hidden_states=hidden_states,
#     778     key_value_states=encoder_hidden_states,
#     779     attention_mask=encoder_attention_mask,
#     780     layer_head_mask=cross_attn_layer_head_mask,
#     781     past_key_value=cross_attn_past_key_value,
#     782     output_attentions=output_attentions,
#     783 )
#     784 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     785 hidden_states = residual + hidden_states
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:273, in BartAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     269     attn_weights_reshaped = None
#     271 attn_probs = nn.functional.dropout(attn_weights, p=self.dropout, training=self.training)
# --> 273 attn_output = torch.bmm(attn_probs, value_states)
#     275 if attn_output.size() != (bsz * self.num_heads, tgt_len, self.head_dim):
#     276     raise ValueError(
#     277         f"`attn_output` should be of size {(bsz * self.num_heads, tgt_len, self.head_dim)}, but is"
#     278         f" {attn_output.size()}"
#     279     )
#
# KeyboardInterrupt:
